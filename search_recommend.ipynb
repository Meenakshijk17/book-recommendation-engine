# %% [markdown]
# # Search Engine

# %% [markdown]
# The datasets are huge (2 - 5 GBs when compressed). Hence reading them in using usual methods would be inefficient. We'll use a streaming method to read the data. We'll read the data without unzipping the file.

# %%
import gzip
with gzip.open("goodreads_books.json.gz", 'r') as f:
    line = f.readline()
line
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %% [markdown]
# This is a single line containing the metadata of a single book.

# %%
import json
json.loads(line)
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %%
# funtion to fetch the required metadata for each of the books
def fetch_metadata(line):
    data = json.loads(line)
    return({
        "book_id": data["book_id"],
        "title": data["title_without_series"],
        "ratings": data["ratings_count"],
        "url": data["url"],
        "cover_image": data["image_url"],
    })

# %%
books_data = []
with gzip.open("goodreads_books.json.gz", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        metadata = fetch_metadata(line)
        try:
            ratings = int(metadata["ratings"])
        except ValueError:
            continue
        if ratings > 20: # take only books with at least 20 ratings
            books_data.append(metadata)

# %%
import pandas as pd

books = pd.DataFrame.from_dict(books_data)
books.head()
# Out:
#    book_id                                              title ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...     140
# 1  6066819                               Best Friends Forever   51184
# 2   287141                      The Aeneid for Boys and Girls      46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...      98
# 4   287149                               The Devil's Notebook     986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171891 entries, 0 to 1171890
# Data columns (total 5 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   book_id      1171891 non-null  object
#  1   title        1171891 non-null  object
#  2   ratings      1171891 non-null  object
#  3   url          1171891 non-null  object
#  4   cover_image  1171891 non-null  object
# dtypes: object(5)
# memory usage: 44.7+ MB

# %%
# checking for na values
books.isna().sum()
# Out:
# book_id        0
# title          0
# ratings        0
# url            0
# cover_image    0
# dtype: int64

# %%
# converting ratings count to numeric (integers)
books['ratings'] = books['ratings'].astype('int')
books.dtypes
# Out:
# book_id        object
# title          object
# ratings         int32
# url            object
# cover_image    object
# dtype: object

# %%
# processing book titles
books['processed_title'] = books['title'].str.lower()
books['processed_title'] = books['processed_title'].str.replace('[^a-z0-9 ]', '', regex=True)
books['processed_title'] = books['processed_title'].str.replace('\s+', ' ', regex=True)
books['processed_title'] = books['processed_title'].str.strip()
books.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                     processed_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
# checking for missing titles (due to invalid (special chars, diff. lang., etc.) original titles)
books[books.processed_title.str.len()==0].head()
# Out:
#      book_id                      title  ratings  \
# 28  28492512              Очир эрхшээгч       82
# 36   1907185             چنین گفت زرتشت      159
# 37   1907184                    بوف کور      704
# 51  18283091              คัมภีร์ร้อยใจ       23
# 61    316994  روانکاو و داستان‌های دیگر       57
#
#                                               url  \
# 28   https://www.goodreads.com/book/show/28492512
# 36  https://www.goodreads.com/book/show/1907185._
# 37  https://www.goodreads.com/book/show/1907184._
# 51   https://www.goodreads.com/book/show/18283091
# 61   https://www.goodreads.com/book/show/316994._
#
#                                           cover_image processed_title
# 28  https://images.gr-assets.com/books/1452330740m...
# 36  https://images.gr-assets.com/books/1397137012m...
# 37  https://images.gr-assets.com/books/1457787423m...
# 51  https://images.gr-assets.com/books/1394964151m...
# 61  https://s.gr-assets.com/assets/nophoto/book/11...

# %%
# removing such lines
books = books[books.processed_title.str.len()>0]
books.shape
# Out:
# (1134094, 6)

# %%
books.to_json('books.json')

# %% [markdown]
# The search engine is developed based on ti-idf values for the terms in the title.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(books.processed_title)

# %%
tfidf
# Out:
# <1134094x213798 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5563366 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

query = "harry potter"
processed = re.sub('[^a-z0-9 ]', '', query.lower().strip()) # same processing done to the titles
query_vec = vectorizer.transform([processed])
similarity = cosine_similarity(query_vec, tfidf).flatten()
indices = np.argpartition(similarity, -10)[-10:] # gives indices of top 10 similar rows
results = books.iloc[indices]
results
# Out:
#           book_id                                              title  ratings  \
# 575636    1508373  Гарри Поттер и философский камень (Harry Potte...       67
# 414996      86940         هاري بوتر وحجر الفيلسوف (Harry Potter, #1)     1290
# 1056149  29546135  ჰარი პოტერი და სიკვდილის საჩუქრები (Harry Pott...       21
# 421292    2089953             הארי פוטר וגביע האש (Harry Potter, #4)       32
# 889764    6352403        הארי פוטר ומסדר עוף החול (Harry Potter, #5)       32
# 889765    6352404         הארי פוטר ואוצרות המוות (Harry Potter, #7)       33
# 1019673   6304297       הארי פוטר והנסיך חצוי-הדם (Harry Potter, #6)       74
# 569477    8479215  هری پاتر و فرمان ققنوس - کتاب پنجم (Harry Pott...       26
# 605227   22601967  ჰარი პოტერი და ფენიქსის ორდენი (Harry Potter, #5)       33
# 535434    8683527  แฮร์รี่ พอตเตอร์กับศิลาอาถรรพ์ (Harry Potter, #1)       84
#
#                                                    url  \
# 575636   https://www.goodreads.com/book/show/1508373._
# 414996     https://www.goodreads.com/book/show/86940._
# 1056149   https://www.goodreads.com/book/show/29546135
# 421292   https://www.goodreads.com/book/show/2089953._
# 889764     https://www.goodreads.com/book/show/6352403
# 889765     https://www.goodreads.com/book/show/6352404
# 1019673  https://www.goodreads.com/book/show/6304297--
# 569477   https://www.goodreads.com/book/show/8479215--
# 605227    https://www.goodreads.com/book/show/22601967
# 535434     https://www.goodreads.com/book/show/8683527
#
#                                                cover_image processed_title
# 575636   https://s.gr-assets.com/assets/nophoto/book/11...  harry potter 1
# 414996   https://images.gr-assets.com/books/1327275224m...  harry potter 1
# 1056149  https://images.gr-assets.com/books/1458298071m...  harry potter 7
# 421292   https://images.gr-assets.com/books/1432676097m...  harry potter 4
# 889764   https://images.gr-assets.com/books/1320636301m...  harry potter 5
# 889765   https://images.gr-assets.com/books/1281662787m...  harry potter 7
# 1019673  https://images.gr-assets.com/books/1349347442m...  harry potter 6
# 569477   https://images.gr-assets.com/books/1279770756m...  harry potter 5
# 605227   https://images.gr-assets.com/books/1404053183m...  harry potter 5
# 535434   https://s.gr-assets.com/assets/nophoto/book/11...  harry potter 1

# %%
query = "twilight"
processed = re.sub('[^a-z0-9 ]', '', query.lower().strip()) # same processing done to the titles
query_vec = vectorizer.transform([processed])
similarity = cosine_similarity(query_vec, tfidf).flatten()
indices = np.argpartition(similarity, -10)[-10:] # gives indices of top 10 similar rows
results = books.iloc[indices]
results
# Out:
#           book_id                    title  ratings  \
# 88144     5953576  Twilight (Twilight, #1)       72
# 283784    6421355  Twilight (Twilight, #1)       83
# 862330   10244455  Twilight (Twilight, #1)      172
# 1103451  11890319                 Twilight       37
# 271722    1026149                 Twilight       36
# 1152725   9979062  Twilight (Twilight, #1)       42
# 763406    5999961  Twilight (Twilight, #1)      398
# 1125587   8516508      خسوف (Twilight, #3)      111
# 69540       12024  Twilight (Twilight, #1)     2405
# 501045     762743  Twilight (Twilight, #1)     7239
#
#                                                        url  \
# 88144    https://www.goodreads.com/book/show/5953576-tw...
# 283784   https://www.goodreads.com/book/show/6421355-tw...
# 862330   https://www.goodreads.com/book/show/10244455-t...
# 1103451  https://www.goodreads.com/book/show/11890319-t...
# 271722   https://www.goodreads.com/book/show/1026149.Tw...
# 1152725  https://www.goodreads.com/book/show/9979062-tw...
# 763406   https://www.goodreads.com/book/show/5999961-tw...
# 1125587  https://www.goodreads.com/book/show/8516508-tw...
# 69540    https://www.goodreads.com/book/show/12024.Twil...
# 501045   https://www.goodreads.com/book/show/762743.Twi...
#
#                                                cover_image  \
# 88144    https://s.gr-assets.com/assets/nophoto/book/11...
# 283784   https://s.gr-assets.com/assets/nophoto/book/11...
# 862330   https://s.gr-assets.com/assets/nophoto/book/11...
# 1103451  https://images.gr-assets.com/books/1315418855m...
# 271722   https://s.gr-assets.com/assets/nophoto/book/11...
# 1152725  https://images.gr-assets.com/books/1488319289m...
# 763406   https://s.gr-assets.com/assets/nophoto/book/11...
# 1125587  https://images.gr-assets.com/books/1315986976m...
# 69540    https://s.gr-assets.com/assets/nophoto/book/11...
# 501045   https://images.gr-assets.com/books/1318007961m...
#
#              processed_title
# 88144    twilight twilight 1
# 283784   twilight twilight 1
# 862330   twilight twilight 1
# 1103451             twilight
# 271722              twilight
# 1152725  twilight twilight 1
# 763406   twilight twilight 1
# 1125587           twilight 3
# 69540    twilight twilight 1
# 501045   twilight twilight 1

# %% [markdown]
# We can see that there are duplicates of the same book. We can try to solve this by taking the row with the highest number of ratings.

# %%
query = "twilight"
processed = re.sub('[^a-z0-9 ]', '', query.lower().strip()) # same processing done to the titles
query_vec = vectorizer.transform([processed])
similarity = cosine_similarity(query_vec, tfidf).flatten()
indices = np.argpartition(similarity, -10)[-10:] # gives indices of top 10 similar rows
results = books.iloc[indices]
results = results.sort_values("ratings", ascending=False)
results.head(5)
# Out:
#           book_id                    title  ratings  \
# 501045     762743  Twilight (Twilight, #1)     7239
# 69540       12024  Twilight (Twilight, #1)     2405
# 763406    5999961  Twilight (Twilight, #1)      398
# 862330   10244455  Twilight (Twilight, #1)      172
# 1125587   8516508      خسوف (Twilight, #3)      111
#
#                                                        url  \
# 501045   https://www.goodreads.com/book/show/762743.Twi...
# 69540    https://www.goodreads.com/book/show/12024.Twil...
# 763406   https://www.goodreads.com/book/show/5999961-tw...
# 862330   https://www.goodreads.com/book/show/10244455-t...
# 1125587  https://www.goodreads.com/book/show/8516508-tw...
#
#                                                cover_image  \
# 501045   https://images.gr-assets.com/books/1318007961m...
# 69540    https://s.gr-assets.com/assets/nophoto/book/11...
# 763406   https://s.gr-assets.com/assets/nophoto/book/11...
# 862330   https://s.gr-assets.com/assets/nophoto/book/11...
# 1125587  https://images.gr-assets.com/books/1315986976m...
#
#              processed_title
# 501045   twilight twilight 1
# 69540    twilight twilight 1
# 763406   twilight twilight 1
# 862330   twilight twilight 1
# 1125587           twilight 3

# %% [markdown]
# We can convert this to a function and do some html formatting for url and cover image columns.

# %%
def url_format(url):
    return(f'<a target="_blank" href="{url}">Goodreads</a>')

def display_image(image):
    return(f'<img src="{image}" width=50></img>')

def search(query, vectorizer):
    processed = re.sub('[^a-z0-9 ]', '', query.lower().strip()) # same processing done to the titles
    query_vec = vectorizer.transform([processed])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -10)[-10:] # gives indices of top 10 similar rows
    results = books.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    return(results.head(5).style.format({'url': url_format, 'cover_image': display_image}))

# %%
search('scarlet pimpernel', vectorizer)
# Out:
# <style  type="text/css" >
# </style><table id="T_d4dd8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >book_id</th>        <th class="col_heading level0 col1" >title</th>        <th class="col_heading level0 col2" >ratings</th>        <th class="col_heading level0 col3" >url</th>        <th class="col_heading level0 col4" >cover_image</th>        <th class="col_heading level0 col5" >processed_title</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d4dd8_level0_row0" class="row_heading level0 row0" >41813</th>
#                         <td id="T_d4dd8_row0_col0" class="data row0 col0" >15833451</td>
#                         <td id="T_d4dd8_row0_col1" class="data row0 col1" >The Scarlet Pimpernel</td>
#                         <td id="T_d4dd8_row0_col2" class="data row0 col2" >1154</td>
#                         <td id="T_d4dd8_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/15833451-the-scarlet-pimpernel">Goodreads</a></td>
#                         <td id="T_d4dd8_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1377281631m/15833451.jpg" width=50></img></td>
#                         <td id="T_d4dd8_row0_col5" class="data row0 col5" >the scarlet pimpernel</td>
#             </tr>
#             <tr>
#                         <th id="T_d4dd8_level0_row1" class="row_heading level0 row1" >898339</th>
#                         <td id="T_d4dd8_row1_col0" class="data row1 col0" >20598360</td>
#                         <td id="T_d4dd8_row1_col1" class="data row1 col1" >The Scarlet Pimpernel</td>
#                         <td id="T_d4dd8_row1_col2" class="data row1 col2" >395</td>
#                         <td id="T_d4dd8_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/20598360-the-scarlet-pimpernel">Goodreads</a></td>
#                         <td id="T_d4dd8_row1_col4" class="data row1 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#                         <td id="T_d4dd8_row1_col5" class="data row1 col5" >the scarlet pimpernel</td>
#             </tr>
#             <tr>
#                         <th id="T_d4dd8_level0_row2" class="row_heading level0 row2" >598791</th>
#                         <td id="T_d4dd8_row2_col0" class="data row2 col0" >18297740</td>
#                         <td id="T_d4dd8_row2_col1" class="data row2 col1" >The Scarlet Pimpernel</td>
#                         <td id="T_d4dd8_row2_col2" class="data row2 col2" >120</td>
#                         <td id="T_d4dd8_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/18297740-the-scarlet-pimpernel">Goodreads</a></td>
#                         <td id="T_d4dd8_row2_col4" class="data row2 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#                         <td id="T_d4dd8_row2_col5" class="data row2 col5" >the scarlet pimpernel</td>
#             </tr>
#             <tr>
#                         <th id="T_d4dd8_level0_row3" class="row_heading level0 row3" >1170788</th>
#                         <td id="T_d4dd8_row3_col0" class="data row3 col0" >7137166</td>
#                         <td id="T_d4dd8_row3_col1" class="data row3 col1" >The Scarlet Pimpernel</td>
#                         <td id="T_d4dd8_row3_col2" class="data row3 col2" >109</td>
#                         <td id="T_d4dd8_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/7137166-the-scarlet-pimpernel">Goodreads</a></td>
#                         <td id="T_d4dd8_row3_col4" class="data row3 col4" ><img src="https://images.gr-assets.com/books/1356158656m/7137166.jpg" width=50></img></td>
#                         <td id="T_d4dd8_row3_col5" class="data row3 col5" >the scarlet pimpernel</td>
#             </tr>
#             <tr>
#                         <th id="T_d4dd8_level0_row4" class="row_heading level0 row4" >334077</th>
#                         <td id="T_d4dd8_row4_col0" class="data row4 col0" >1444468</td>
#                         <td id="T_d4dd8_row4_col1" class="data row4 col1" >The Scarlet Pimpernel</td>
#                         <td id="T_d4dd8_row4_col2" class="data row4 col2" >82</td>
#                         <td id="T_d4dd8_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/1444468.The_Scarlet_Pimpernel">Goodreads</a></td>
#                         <td id="T_d4dd8_row4_col4" class="data row4 col4" ><img src="https://images.gr-assets.com/books/1320503110m/1444468.jpg" width=50></img></td>
#                         <td id="T_d4dd8_row4_col5" class="data row4 col5" >the scarlet pimpernel</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Recommendation Engine

# %%
books_i_like = ['4837599', '762743', '86940', '9571725', '1392526', '15833451']

# %%
book_id_map = {}
with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        id, book_id = line.split(',')
        book_id_map[id] = book_id.split('\n')[0]

# %%
similar_users = set() # fetching users who have rated the books I like >= 4
with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, id, _, rating, _ = line.split(",")
        
        if user_id in similar_users:
            continue
            
        try:
            rating = int(rating)
        except ValueError:
            continue
            
        book_id = book_id_map[id]
        
        if (book_id in books_i_like) and (rating >= 4):
            similar_users.add(user_id)

# %%
books_rated_by_similar_users = [] # fetching the books rated by the above users
with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, id, _, rating, _ = line.split(",")
        
        if user_id in similar_users:
            book_id = book_id_map[id]
            books_rated_by_similar_users.append([user_id, book_id, rating])

# %%
import pandas

recommended_books = pd.DataFrame(books_rated_by_similar_users, columns=['user_id', 'book_id', 'rating'])
recommended_books.head()
# Out:
#   user_id   book_id rating
# 0     356  13597801      5
# 1     356  13641946      4
# 2     356  13101894      4
# 3     356    762743      4
# 4     356     42900      5

# %%
top_recommended_books = recommended_books.book_id.value_counts().head(10) # top 10 recommended books
top_recommended_books.head()
# Out:
# 2767052    699
# 1162543    674
# 762743     654
# 6148028    634
# 428263     620
# Name: book_id, dtype: int64

# %%
top_recommended_books = top_recommended_books.index.values

# %%
books = pd.read_json("books.json")
books.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                     processed_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %%
top_recommended_books = [str(book_id) for book_id in top_recommended_books]
books['book_id'] = books['book_id'].astype('str')

# %%
books[books.book_id.isin(top_recommended_books)]
# Out:
#         book_id                                              title  ratings  \
# 65983   7260188                  Mockingjay (The Hunger Games, #3)  1743362
# 255053  2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 316186    49041                            New Moon (Twilight, #2)  1161751
# 361102  1162543                       Breaking Dawn (Twilight, #4)  1078310
# 501045   762743                            Twilight (Twilight, #1)     7239
# 746012  6148028               Catching Fire (The Hunger Games, #2)  1854746
# 786647        3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 808272   136251  Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 852869   428263                             Eclipse (Twilight, #3)  1146155
# 891116    15881  Harry Potter and the Chamber of Secrets (Harry...  1821802
#
#                                                       url  \
# 65983   https://www.goodreads.com/book/show/7260188-mo...
# 255053  https://www.goodreads.com/book/show/2767052-th...
# 316186  https://www.goodreads.com/book/show/49041.New_...
# 361102  https://www.goodreads.com/book/show/1162543.Br...
# 501045  https://www.goodreads.com/book/show/762743.Twi...
# 746012  https://www.goodreads.com/book/show/6148028-ca...
# 786647  https://www.goodreads.com/book/show/3.Harry_Po...
# 808272  https://www.goodreads.com/book/show/136251.Har...
# 852869  https://www.goodreads.com/book/show/428263.Ecl...
# 891116  https://www.goodreads.com/book/show/15881.Harr...
#
#                                               cover_image  \
# 65983   https://images.gr-assets.com/books/1358275419m...
# 255053  https://images.gr-assets.com/books/1447303603m...
# 316186  https://images.gr-assets.com/books/1361039440m...
# 361102  https://images.gr-assets.com/books/1361039438m...
# 501045  https://images.gr-assets.com/books/1318007961m...
# 746012  https://images.gr-assets.com/books/1358273780m...
# 786647  https://images.gr-assets.com/books/1474154022m...
# 808272  https://images.gr-assets.com/books/1474171184m...
# 852869  https://images.gr-assets.com/books/1361038355m...
# 891116  https://images.gr-assets.com/books/1474169725m...
#
#                                           processed_title
# 65983                       mockingjay the hunger games 3
# 255053                the hunger games the hunger games 1
# 316186                                new moon twilight 2
# 361102                           breaking dawn twilight 4
# 501045                                twilight twilight 1
# 746012                   catching fire the hunger games 2
# 786647  harry potter and the sorcerers stone harry pot...
# 808272  harry potter and the deathly hallows harry pot...
# 852869                                 eclipse twilight 3
# 891116  harry potter and the chamber of secrets harry ...

# %% [markdown]
# The books given here are generally popular books. We need a list that actually is custom-made to our liking. We try to penalise the popularity of the recommended books.

# %%
all_recommended_books = recommended_books.book_id.value_counts().reset_index()
all_recommended_books.columns = ["book_id", "book_count"]
all_recommended_books["book_id"] = all_recommended_books['book_id'].astype('str')

all_recommended_books = all_recommended_books.merge(books, on="book_id", how="inner")
all_recommended_books.head()
# Out:
#    book_id  book_count                                    title  ratings  \
# 0  2767052         699  The Hunger Games (The Hunger Games, #1)  4899965
# 1  1162543         674             Breaking Dawn (Twilight, #4)  1078310
# 2   762743         654                  Twilight (Twilight, #1)     7239
# 3  6148028         634     Catching Fire (The Hunger Games, #2)  1854746
# 4   428263         620                   Eclipse (Twilight, #3)  1146155
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/2767052-th...
# 1  https://www.goodreads.com/book/show/1162543.Br...
# 2  https://www.goodreads.com/book/show/762743.Twi...
# 3  https://www.goodreads.com/book/show/6148028-ca...
# 4  https://www.goodreads.com/book/show/428263.Ecl...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1361039438m...
# 2  https://images.gr-assets.com/books/1318007961m...
# 3  https://images.gr-assets.com/books/1358273780m...
# 4  https://images.gr-assets.com/books/1361038355m...
#
#                        processed_title
# 0  the hunger games the hunger games 1
# 1             breaking dawn twilight 4
# 2                  twilight twilight 1
# 3     catching fire the hunger games 2
# 4                   eclipse twilight 3

# %%
all_recommended_books["penalised_score"] = all_recommended_books["book_count"] * all_recommended_books["book_count"]/all_recommended_books["ratings"]

# %%
all_recommended_books.sort_values('penalised_score', ascending=False).head(10)
# Out:
#        book_id  book_count                                        title  \
# 2       762743         654                      Twilight (Twilight, #1)
# 102      86940         228   هاري بوتر وحجر الفيلسوف (Harry Potter, #1)
# 51     9571725         284                 Murder on the Orient Express
# 2104  24909347          45            Obsidio (The Illuminae Files, #3)
# 201    7809996         165   هاري بوتر وحجرة الأسرار (Harry Potter, #2)
# 320      49839         137      هاري بوتر وكأس النار (Harry Potter, #4)
# 304      49869         141   هاري بوتر وسجين أزكابان (Harry Potter, #3)
# 382      70355         125  هاري بوتر وجماعة العنقاء (Harry Potter, #5)
# 604    1392526          97                            The Da Vinci Code
# 8647  36307629          17            King of Scars (King of Scars, #1)
#
#       ratings                                                url  \
# 2        7239  https://www.goodreads.com/book/show/762743.Twi...
# 102      1290        https://www.goodreads.com/book/show/86940._
# 51       2136  https://www.goodreads.com/book/show/9571725-mu...
# 2104       82  https://www.goodreads.com/book/show/24909347-o...
# 201      1117        https://www.goodreads.com/book/show/7809996
# 320       957        https://www.goodreads.com/book/show/49839._
# 304      1023        https://www.goodreads.com/book/show/49869._
# 382       955        https://www.goodreads.com/book/show/70355._
# 604       695  https://www.goodreads.com/book/show/1392526.Th...
# 8647       22  https://www.goodreads.com/book/show/36307629-k...
#
#                                             cover_image  \
# 2     https://images.gr-assets.com/books/1318007961m...
# 102   https://images.gr-assets.com/books/1327275224m...
# 51    https://images.gr-assets.com/books/1409605149m...
# 2104  https://images.gr-assets.com/books/1501704611m...
# 201   https://s.gr-assets.com/assets/nophoto/book/11...
# 320   https://images.gr-assets.com/books/1312417199m...
# 304   https://images.gr-assets.com/books/1329651788m...
# 382   https://images.gr-assets.com/books/1351790790m...
# 604   https://images.gr-assets.com/books/1361688983m...
# 8647  https://images.gr-assets.com/books/1506962795m...
#
#                     processed_title  penalised_score
# 2               twilight twilight 1        59.084956
# 102                  harry potter 1        40.297674
# 51     murder on the orient express        37.760300
# 2104  obsidio the illuminae files 3        24.695122
# 201                  harry potter 2        24.373321
# 320                  harry potter 4        19.612330
# 304                  harry potter 3        19.434018
# 382                  harry potter 5        16.361257
# 604               the da vinci code        13.538129
# 8647  king of scars king of scars 1        13.136364

# %% [markdown]
# Note that now, books with low number of ratings have also turned up in the list. Also, some of these books are already in the liked book list.
#
# Now, we can choose to have a cut-off to the number of ratings.

# %%
popular_recommended_books = all_recommended_books[all_recommended_books.book_count>75].sort_values('penalised_score', ascending=False)

# %%
popular_recommended_books[~popular_recommended_books.book_id.isin(books_i_like)].head(10).style.format({'url': url_format, 'cover_image': display_image})
# Out:
# <style  type="text/css" >
# </style><table id="T_14e65_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >book_id</th>        <th class="col_heading level0 col1" >book_count</th>        <th class="col_heading level0 col2" >title</th>        <th class="col_heading level0 col3" >ratings</th>        <th class="col_heading level0 col4" >url</th>        <th class="col_heading level0 col5" >cover_image</th>        <th class="col_heading level0 col6" >processed_title</th>        <th class="col_heading level0 col7" >penalised_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14e65_level0_row0" class="row_heading level0 row0" >201</th>
#                         <td id="T_14e65_row0_col0" class="data row0 col0" >7809996</td>
#                         <td id="T_14e65_row0_col1" class="data row0 col1" >165</td>
#                         <td id="T_14e65_row0_col2" class="data row0 col2" >هاري بوتر وحجرة الأسرار (Harry Potter, #2)</td>
#                         <td id="T_14e65_row0_col3" class="data row0 col3" >1117</td>
#                         <td id="T_14e65_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/7809996">Goodreads</a></td>
#                         <td id="T_14e65_row0_col5" class="data row0 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#                         <td id="T_14e65_row0_col6" class="data row0 col6" >harry potter 2</td>
#                         <td id="T_14e65_row0_col7" class="data row0 col7" >24.373321</td>
#             </tr>
#             <tr>
#                         <th id="T_14e65_level0_row1" class="row_heading level0 row1" >320</th>
#                         <td id="T_14e65_row1_col0" class="data row1 col0" >49839</td>
#                         <td id="T_14e65_row1_col1" class="data row1 col1" >137</td>
#                         <td id="T_14e65_row1_col2" class="data row1 col2" >هاري بوتر وكأس النار (Harry Potter, #4)</td>
#                         <td id="T_14e65_row1_col3" class="data row1 col3" >957</td>
#                         <td id="T_14e65_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/49839._">Goodreads</a></td>
#                         <td id="T_14e65_row1_col5" class="data row1 col5" ><img src="https://images.gr-assets.com/books/1312417199m/49839.jpg" width=50></img></td>
#                         <td id="T_14e65_row1_col6" class="data row1 col6" >harry potter 4</td>
#                         <td id="T_14e65_row1_col7" class="data row1 col7" >19.612330</td>
#             </tr>
#             <tr>
#                         <th id="T_14e65_level0_row2" class="row_heading level0 row2" >304</th>
#                         <td id="T_14e65_row2_col0" class="data row2 col0" >49869</td>
#                         <td id="T_14e65_row2_col1" class="data row2 col1" >141</td>
#                         <td id="T_14e65_row2_col2" class="data row2 col2" >هاري بوتر وسجين أزكابان (Harry Potter, #3)</td>
#                         <td id="T_14e65_row2_col3" class="data row2 col3" >1023</td>
#                         <td id="T_14e65_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/49869._">Goodreads</a></td>
#                         <td id="T_14e65_row2_col5" class="data row2 col5" ><img src="https://images.gr-assets.com/books/1329651788m/49869.jpg" width=50></img></td>
#                         <td id="T_14e65_row2_col6" class="data row2 col6" >harry potter 3</td>
#                         <td id="T_14e65_row2_col7" class="data row2 col7" >19.434018</td>
#             </tr>
#             <tr>
#                         <th id="T_14e65_level0_row3" class="row_heading level0 row3" >382</th>
#                         <td id="T_14e65_row3_col0" class="data row3 col0" >70355</td>
#                         <td id="T_14e65_row3_col1" class="data row3 col1" >125</td>
#                         <td id="T_14e65_row3_col2" class="data row3 col2" >هاري بوتر وجماعة العنقاء (Harry Potter, #5)</td>
#                         <td id="T_14e65_row3_col3" class="data row3 col3" >955</td>
#                         <td id="T_14e65_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/70355._">Goodreads</a></td>
#                         <td id="T_14e65_row3_col5" class="data row3 col5" ><img src="https://images.gr-assets.com/books/1351790790m/70355.jpg" width=50></img></td>
#                         <td id="T_14e65_row3_col6" class="data row3 col6" >harry potter 5</td>
#                         <td id="T_14e65_row3_col7" class="data row3 col7" >16.361257</td>
#             </tr>
#             <tr>
#                         <th id="T_14e65_level0_row4" class="row_heading level0 row4" >366</th>
#                         <td id="T_14e65_row4_col0" class="data row4 col0" >563012</td>
#                         <td id="T_14e65_row4_col1" class="data row4 col1" >128</td>
#                         <td id="T_14e65_row4_col2" class="data row4 col2" >New Moon (Twilight, #2)</td>
#                         <td id="T_14e65_row4_col3" class="data row4 col3" >2497</td>
#                         <td id="T_14e65_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/563012.New_Moon">Goodreads</a></td>
#                         <td id="T_14e65_row4_col5" class="data row4 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#                         <td id="T_14e65_row4_col6" class="data row4 col6" >new moon twilight 2</td>
#                         <td id="T_14e65_row4_col7" class="data row4 col7" >6.561474</td>
#             </tr>
#             <tr>
#                         <th id="T_14e65_level0_row5" class="row_heading level0 row5" >923</th>
#                         <td id="T_14e65_row5_col0" class="data row5 col0" >6138606</td>
#                         <td id="T_14e65_row5_col1" class="data row5 col1" >76</td>
#                         <td id="T_14e65_row5_col2" class="data row5 col2" >The Seeker (The Host, #2)</td>
#                         <td id="T_14e65_row5_col3" class="data row5 col3" >1600</td>
#                         <td id="T_14e65_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/6138606-the-seeker">Goodreads</a></td>
#                         <td id="T_14e65_row5_col5" class="data row5 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#                         <td id="T_14e65_row5_col6" class="data row5 col6" >the seeker the host 2</td>
#                         <td id="T_14e65_row5_col7" class="data row5 col7" >3.610000</td>
#             </tr>
#             <tr>
#                         <th id="T_14e65_level0_row6" class="row_heading level0 row6" >643</th>
#                         <td id="T_14e65_row6_col0" class="data row6 col0" >332572</td>
#                         <td id="T_14e65_row6_col1" class="data row6 col1" >93</td>
#                         <td id="T_14e65_row6_col2" class="data row6 col2" >Eclipse (Twilight, #3)</td>
#                         <td id="T_14e65_row6_col3" class="data row6 col3" >3681</td>
#                         <td id="T_14e65_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/332572.Eclipse">Goodreads</a></td>
#                         <td id="T_14e65_row6_col5" class="data row6 col5" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#                         <td id="T_14e65_row6_col6" class="data row6 col6" >eclipse twilight 3</td>
#                         <td id="T_14e65_row6_col7" class="data row6 col7" >2.349633</td>
#             </tr>
#             <tr>
#                         <th id="T_14e65_level0_row7" class="row_heading level0 row7" >820</th>
